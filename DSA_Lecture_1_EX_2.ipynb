# %%
# Create a dictionary named 'college'
college = {
    "name": "ABC Institute",   # College name
    "departments": [           # List of departments
        {
            "name": "CSE",     # First department name
            "students": 120    # Number of students in CSE
        },
        {
            "name": "ECE",     # Second department name
            "students": 90     # Number of students in ECE
        }
    ]
}

# Print the name of the first department
print(college["departments"][0]["name"])
# Out:
# CSE
