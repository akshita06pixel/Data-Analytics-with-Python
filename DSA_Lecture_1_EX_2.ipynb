# %%
# Create a dictionary to store student information
student = {
    "Name": "Amit",
    "Age": 21,
    "Marks": 85
}

# Print the complete dictionary
print(student)

# Print the data type of the variable 'student'
print(type(student))
# Out:
# {'Name': 'Amit', 'Age': 21, 'Marks': 85}
# <class 'dict'>
