# %% [markdown]
# <a href="https://colab.research.google.com/github/akshita06pixel/Data-Analytics-with-Python/blob/main/DSA_Lecture_1_EX_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a dictionary to store student information
student = {
    "Name": "Amit",
    "Age": 21,
    "Marks": 85
}

# Print the complete dictionary
print(student)

# Print the data type of the variable 'student'
print(type(student))
# Out:
# {'Name': 'Amit', 'Age': 21, 'Marks': 85}
# <class 'dict'>
